# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Flatten,Dense

# %%
data = pd.read_csv("/content/emotions.csv")
data.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
data=data.drop("tweet_id",axis=1)
data.head()
# Out:
#     sentiment                                            content
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
data["sentiment"].value_counts()
# Out:
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: sentiment, dtype: int64

# %%
for i,row in data.iterrows():
  if '@' in row['content']:
    data = data.drop(i)

# %%
data.head()
# Out:
#     sentiment                                            content
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 6     sadness  I should be sleep, but im not! thinking about ...
# 7       worry               Hmmm. http://www.djhero.com/ is down

# %%
data["sentiment"].value_counts()
# Out:
# worry         4749
# neutral       4046
# sadness       3070
# happiness     2623
# love          1892
# surprise      1020
# relief         847
# hate           815
# fun            791
# empty          420
# enthusiasm     369
# boredom        129
# anger           63
# Name: sentiment, dtype: int64

# %%
unique_sentiments=data['sentiment'].unique()
unique_sentiments
# Out:
# array(['sadness', 'enthusiasm', 'worry', 'neutral', 'surprise', 'fun',
#        'hate', 'happiness', 'boredom', 'love', 'relief', 'empty', 'anger'],
#       dtype=object)

# %%
sentiment_arrays={}
for sentiment in unique_sentiments:
    sentiment_array = data[data["sentiment"] == sentiment]["content"].values
    sentiment_arrays[sentiment] = sentiment_array

# %%
anger=sentiment_arrays['anger']
worry = np.random.choice(sentiment_arrays['worry'],anger.shape)
neutral = np.random.choice(sentiment_arrays['neutral'],anger.shape)
sadness = np.random.choice(sentiment_arrays['sadness'],anger.shape)
happiness = np.random.choice(sentiment_arrays['happiness'],anger.shape)
love = np.random.choice(sentiment_arrays['love'],anger.shape)
surprise  = np.random.choice(sentiment_arrays['surprise'],anger.shape)
relief = np.random.choice(sentiment_arrays['relief'],anger.shape)
hate = np.random.choice(sentiment_arrays['hate'],anger.shape)
fun = np.random.choice(sentiment_arrays['fun'],anger.shape)
empty = np.random.choice(sentiment_arrays['empty'],anger.shape)
enthusiasm = np.random.choice(sentiment_arrays['enthusiasm'],anger.shape)
boredom = np.random.choice(sentiment_arrays['boredom'],anger.shape)

# %%
data=pd.DataFrame({"anger":anger,
                      "worry":worry,
                       "neutral":neutral,
                       "sadness":sadness,
                       "happiness":happiness,
                       "love":love,
                       "surprise":surprise,
                       "relief":relief,
                       "hate":hate,
                       "fun":fun,
                       "empty":empty,
                       "enthusiasm":enthusiasm,
                       "boredom":boredom})
data.head(3)
# Out:
#                               anger  \
# 0             fuckin'm transtelecom
# 1  Working   But it's Fridaaaayyyyy
# 2        Packing  I don't like it..
#
#                                                worry  \
# 0   Ugh my neck really hurts  I'm out aquatards, xox
# 1  Still unbelievably shocked about the firing of...
# 2            argh! my embouchure= FAIL! makes me sad
#
#                                      neutral  \
# 0                    watching short stack tv
# 1  is desperate to go to the venice beinnale
# 2                     ARGH!! watching batman
#
#                                              sadness  \
# 0  Starving. And Alyssa's mom would bring her sub...
# 1          My truss failing  http://yfrog.com/154upj
# 2  Lovin  the clean shaven Mr Flowers!  He looks ...
#
#                                            happiness  \
# 0  finally home!! tomorrow is day 2 of &quot;Amaz...
# 1  Woot. just had my interview! went awsome! I di...
# 2  SWAY SWAY BABY zommgg love it  need more screa...
#
#                                                 love  \
# 0                  just had a bbq... YUM im full now
# 1  My purple pusrse is pretty  someone tell Katie...
# 2  Mother's day has already began! Congratulation...
#
#                                             surprise  \
# 0                                          Wedding..
# 1  forgot she had a Twitter account.    Happy Mot...
# 2                Just getting an additional free day
#
#                                               relief  \
# 0         Can't I just be a stay at home mom already
# 1  sunnn finnalllyyy!!  aint slept :| need some s...
# 2                      It worked. Cool AND the gang!
#
#                                                 hate  \
# 0  I hate the new mt dew commercial..the one with...
# 1  FML. . .i have the worst paper cut on my knuck...
# 2  Feel like crap today   Got a speeding ticket 1...
#
#                                                  fun  \
# 0  I haven't gone sheesha smoking in a loooong ti...
# 1  8:30PM... it has just hit me i have school tom...
# 2  I haven't gone sheesha smoking in a loooong ti...
#
#                                                empty  \
# 0  Cold day :/ Studing all day long to the tests ...
# 1  Currently working on a collab with Alynn Carte...
# 2  is fairly upset at the fact the twitter/bgt se...
#
#                                           enthusiasm  \
# 0  why do we even live on this earth ?? i wanna l...
# 1  did some more work on Dig Dug. can get to leve...
# 2                 I'm going to go check out DJ Volt.
#
#                                              boredom
# 0                 Ugh... Waiting.... Interminable...
# 1  got new sneaks today..can't wait to break them...
# 2  ok its been one hour im still waiting im losin...

# %%
pp_data=pd.melt(data,var_name='sentiment',value_name="content")
pp_data.head(100)
# Out:
#    sentiment                                            content
# 0      anger                              fuckin'm transtelecom
# 1      anger                   Working   But it's Fridaaaayyyyy
# 2      anger                         Packing  I don't like it..
# 3      anger  I tried to dye my hair and all i got was a blo...
# 4      anger  &quot;locked up abroad&quot; makes bein half b...
# ..       ...                                                ...
# 95     worry                  he's back! meeting him in 40 mins
# 96     worry         awwww bless her  she needs another chance.
# 97     worry  finally off to bed almost everything is packed...
# 98     worry          getting my phone back this week  yeeeewww
# 99     worry  So bummed that I can't see LTJ in June  hoping...
#
# [100 rows x 2 columns]

# %%
pp_data['sentiment'].value_counts()
# Out:
# anger         63
# worry         63
# neutral       63
# sadness       63
# happiness     63
# love          63
# surprise      63
# relief        63
# hate          63
# fun           63
# empty         63
# enthusiasm    63
# boredom       63
# Name: sentiment, dtype: int64

# %%
sentiment_mapping = {'worry': 1,'neutral': 2,'sadness': 3,'happiness': 4,'love': 5,
                     'surprise': 6,'relief': 7,'hate': 8,'fun': 9,'empty': 10,
                     'enthusiasm': 11,'boredom': 12,'anger': 13}
for i,val in pp_data.sentiment.items():
  if val in sentiment_mapping:
    pp_data.at[i,'sentiment'] = sentiment_mapping[val]

# %%
display(type(pp_data.sentiment))
labels=list(pp_data.sentiment)
type(labels)
# Out:
# pandas.core.series.Series
# list

# %%
pp_data.head(5)
# Out:
#   sentiment                                            content
# 0        13                              fuckin'm transtelecom
# 1        13                   Working   But it's Fridaaaayyyyy
# 2        13                         Packing  I don't like it..
# 3        13  I tried to dye my hair and all i got was a blo...
# 4        13  &quot;locked up abroad&quot; makes bein half b...

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(pp_data.content)
sequences= tokenizer.texts_to_sequences(pp_data.content)
padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences)

# %%
padded_sequences.shape
# Out:
# (819, 33)

# %%
model = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=8, input_length=padded_sequences.shape[1]),
    Flatten(),
    Dense(16, activation='sigmoid'),
    Dense(14, activation='softmax')])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(padded_sequences,np.array(labels),epochs=10)
# Out:
# Epoch 1/10
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1963 - accuracy: 0.9292
# Epoch 2/10
# 26/26 [==============================] - 0s 3ms/step - loss: 1.1384 - accuracy: 0.9389
# Epoch 3/10
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0836 - accuracy: 0.9475
# Epoch 4/10
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0311 - accuracy: 0.9524
# Epoch 5/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9785 - accuracy: 0.9585
# Epoch 6/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9299 - accuracy: 0.9621
# Epoch 7/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8821 - accuracy: 0.9683
# Epoch 8/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8368 - accuracy: 0.9683
# Epoch 9/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7944 - accuracy: 0.9707
# Epoch 10/10
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7535 - accuracy: 0.9805

# %%
test_sentence = "i am very angry because the model is not working properly"
test_sequence = tokenizer.texts_to_sequences([test_sentence])
test_padded_sequence = tf.keras.preprocessing.sequence.pad_sequences(test_sequence, maxlen=padded_sequences.shape[1])

prediction = model.predict(test_padded_sequence)
# Out:
# 1/1 [==============================] - 0s 96ms/step

# %%
ind = np.argmax(prediction)
predt_label=list(sentiment_mapping)
predt_label[ind]
# Out:
# 'boredom'

# %%
model.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
